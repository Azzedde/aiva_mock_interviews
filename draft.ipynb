# %%
from faster_whisper import WhisperModel

model_size = "large-v3"

# Run on GPU with FP16
# model = WhisperModel(model_size, device="cuda", compute_type="float16")

# or run on GPU with INT8
# model = WhisperModel(model_size, device="cuda", compute_type="int8_float16")
# or run on CPU with INT8
model = WhisperModel(model_size, device="cpu", compute_type="int8")

segments, info = model.transcribe("audio.mp3", beam_size=5)

print("Detected language '%s' with probability %f" % (info.language, info.language_probability))

for segment in segments:
    print("[%.2fs -> %.2fs] %s" % (segment.start, segment.end, segment.text))
# Out:
# An error occured while synchronizing the model Systran/faster-whisper-large-v3 from the Hugging Face Hub:
# 401 Client Error. (Request ID: Root=1-679baa9e-039f3a9210e0ef5d44b6eb99;433cee46-e0b7-4735-ad75-a80ceafda6a4)
#
# Repository Not Found for url: https://huggingface.co/api/models/Systran/faster-whisper-large-v3/revision/main.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated.
# Invalid credentials in Authorization header
# Trying to load the model directly from the local cache, if it exists.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/utils/_errors.py:304, in hf_raise_for_status(response, endpoint_name)
#     303 try:
# --> 304     response.raise_for_status()
#     305 except HTTPError as e:
#
# File ~/.local/lib/python3.10/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/models/Systran/faster-whisper-large-v3/revision/main
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/faster_whisper/utils.py:107, in download_model(size_or_id, output_dir, local_files_only, cache_dir)
#     106 try:
# --> 107     return huggingface_hub.snapshot_download(repo_id, **kwargs)
#     108 except (
#     109     huggingface_hub.utils.HfHubHTTPError,
#     110     requests.exceptions.ConnectionError,
#     111 ) as exception:
#
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/_snapshot_download.py:233, in snapshot_download(repo_id, repo_type, revision, cache_dir, local_dir, library_name, library_version, user_agent, proxies, etag_timeout, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class, headers, endpoint, local_dir_use_symlinks, resume_download)
#     231 elif isinstance(api_call_error, RepositoryNotFoundError) or isinstance(api_call_error, GatedRepoError):
#     232     # Repo not found => let's raise the actual error
# --> 233     raise api_call_error
#     234 else:
#     235     # Otherwise: most likely a connection issue or Hub downtime => let's warn the user
#
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/_snapshot_download.py:164, in snapshot_download(repo_id, repo_type, revision, cache_dir, local_dir, library_name, library_version, user_agent, proxies, etag_timeout, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class, headers, endpoint, local_dir_use_symlinks, resume_download)
#     157     api = HfApi(
#     158         library_name=library_name,
#     159         library_version=library_version,
#    (...)
#     162         headers=headers,
#     163     )
# --> 164     repo_info = api.repo_info(repo_id=repo_id, repo_type=repo_type, revision=revision, token=token)
#     165 except (requests.exceptions.SSLError, requests.exceptions.ProxyError):
#     166     # Actually raise for those subclasses of ConnectionError
#
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/hf_api.py:2491, in HfApi.repo_info(self, repo_id, revision, repo_type, timeout, files_metadata, token)
#    2490     raise ValueError("Unsupported repo type.")
# -> 2491 return method(
#    2492     repo_id,
#    2493     revision=revision,
#    2494     token=token,
#    2495     timeout=timeout,
#    2496     files_metadata=files_metadata,
#    2497 )
#
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/hf_api.py:2301, in HfApi.model_info(self, repo_id, revision, timeout, securityStatus, files_metadata, token)
#    2300 r = get_session().get(path, headers=headers, timeout=timeout, params=params)
# -> 2301 hf_raise_for_status(r)
#    2302 data = r.json()
#
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/utils/_errors.py:352, in hf_raise_for_status(response, endpoint_name)
#     344     message = (
#     345         f"{response.status_code} Client Error."
#     346         + "\n\n"
#    (...)
#     350         " make sure you are authenticated."
#     351     )
# --> 352     raise RepositoryNotFoundError(message, response) from e
#     354 elif response.status_code == 400:
#
# RepositoryNotFoundError: 401 Client Error. (Request ID: Root=1-679baa9e-039f3a9210e0ef5d44b6eb99;433cee46-e0b7-4735-ad75-a80ceafda6a4)
#
# Repository Not Found for url: https://huggingface.co/api/models/Systran/faster-whisper-large-v3/revision/main.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated.
# Invalid credentials in Authorization header
#
# During handling of the above exception, another exception occurred:
#
# LocalEntryNotFoundError                   Traceback (most recent call last)
# Cell In[1], line 11
#       3 model_size = "large-v3"
#       5 # Run on GPU with FP16
#       6 # model = WhisperModel(model_size, device="cuda", compute_type="float16")
#       7
#       8 # or run on GPU with INT8
#       9 # model = WhisperModel(model_size, device="cuda", compute_type="int8_float16")
#      10 # or run on CPU with INT8
# ---> 11 model = WhisperModel(model_size, device="cpu", compute_type="int8")
#      13 segments, info = model.transcribe("audio.mp3", beam_size=5)
#      15 print("Detected language '%s' with probability %f" % (info.language, info.language_probability))
#
# File ~/.local/lib/python3.10/site-packages/faster_whisper/transcribe.py:641, in WhisperModel.__init__(self, model_size_or_path, device, device_index, compute_type, cpu_threads, num_workers, download_root, local_files_only, files, **model_kwargs)
#     639     model_path = model_size_or_path
#     640 else:
# --> 641     model_path = download_model(
#     642         model_size_or_path,
#     643         local_files_only=local_files_only,
#     644         cache_dir=download_root,
#     645     )
#     647 self.model = ctranslate2.models.Whisper(
#     648     model_path,
#     649     device=device,
#    (...)
#     655     **model_kwargs,
#     656 )
#     658 tokenizer_file = os.path.join(model_path, "tokenizer.json")
#
# File ~/.local/lib/python3.10/site-packages/faster_whisper/utils.py:123, in download_model(size_or_id, output_dir, local_files_only, cache_dir)
#     118 logger.warning(
#     119     "Trying to load the model directly from the local cache, if it exists."
#     120 )
#     122 kwargs["local_files_only"] = True
# --> 123 return huggingface_hub.snapshot_download(repo_id, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/huggingface_hub/_snapshot_download.py:220, in snapshot_download(repo_id, repo_type, revision, cache_dir, local_dir, library_name, library_version, user_agent, proxies, etag_timeout, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class, headers, endpoint, local_dir_use_symlinks, resume_download)
#     218 # If we couldn't find the appropriate folder on disk, raise an error.
#     219 if local_files_only:
# --> 220     raise LocalEntryNotFoundError(
#     221         "Cannot find an appropriate cached snapshot folder for the specified revision on the local disk and "
#     222         "outgoing traffic has been disabled. To enable repo look-ups and downloads online, pass "
#     223         "'local_files_only=False' as input."
#     224     )
#     225 elif isinstance(api_call_error, OfflineModeIsEnabled):
#     226     raise LocalEntryNotFoundError(
#     227         "Cannot find an appropriate cached snapshot folder for the specified revision on the local disk and "
#     228         "outgoing traffic has been disabled. To enable repo look-ups and downloads online, set "
#     229         "'HF_HUB_OFFLINE=0' as environment variable."
#     230     ) from api_call_error
#
# LocalEntryNotFoundError: Cannot find an appropriate cached snapshot folder for the specified revision on the local disk and outgoing traffic has been disabled. To enable repo look-ups and downloads online, pass 'local_files_only=False' as input.
